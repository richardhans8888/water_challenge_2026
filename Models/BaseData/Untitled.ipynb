# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the two submission files
submission_0 = pd.read_csv('submission.csv')

# Set up the plot grid (1 row, 3 columns)
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Plot the Total Alkalinity for both files
axes[0].plot(submission_0.index, submission_0['Total Alkalinity'], label="submission.csv", color='blue', alpha=0.7)
axes[0].plot(submission_1.index, submission_1['Total Alkalinity'], label="submission_1.csv", color='orange', alpha=0.7)
axes[0].set_title('Total Alkalinity')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Total Alkalinity')
axes[0].legend()

# Plot the Electrical Conductance for both files
axes[1].plot(submission_0.index, submission_0['Electrical Conductance'], label="submission.csv", color='blue', alpha=0.7)
axes[1].plot(submission_1.index, submission_1['Electrical Conductance'], label="submission_1.csv", color='orange', alpha=0.7)
axes[1].set_title('Electrical Conductance')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Electrical Conductance')
axes[1].legend()

# Plot the Dissolved Reactive Phosphorus for both files
axes[2].plot(submission_0.index, submission_0['Dissolved Reactive Phosphorus'], label="submission.csv", color='blue', alpha=0.7)
axes[2].plot(submission_1.index, submission_1['Dissolved Reactive Phosphorus'], label="submission_1.csv", color='orange', alpha=0.7)
axes[2].set_title('Dissolved Reactive Phosphorus')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Dissolved Reactive Phosphorus')
axes[2].legend()

# Adjust layout for tight spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the submission_1 file (submission_1.csv)
submission_1 = pd.read_csv('submission_1.csv')

# Set up the plot grid (1 row, 3 columns)
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Plot the Total Alkalinity
axes[0].plot(submission_1.index, submission_1['Total Alkalinity'], color='orange')
axes[0].set_title('Total Alkalinity')
axes[0].set_xlabel('Index')
axes[0].set_ylabel('Total Alkalinity')

# Plot the Electrical Conductance
axes[1].plot(submission_1.index, submission_1['Electrical Conductance'], color='orange')
axes[1].set_title('Electrical Conductance')
axes[1].set_xlabel('Index')
axes[1].set_ylabel('Electrical Conductance')

# Plot the Dissolved Reactive Phosphorus
axes[2].plot(submission_1.index, submission_1['Dissolved Reactive Phosphorus'], color='orange')
axes[2].set_title('Dissolved Reactive Phosphorus')
axes[2].set_xlabel('Index')
axes[2].set_ylabel('Dissolved Reactive Phosphorus')

# Adjust layout for tight spacing
plt.tight_layout()

# Show the plot
plt.show()
