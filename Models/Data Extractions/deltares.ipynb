# %%
import pandas as pd
import numpy as np
import json
import fsspec
import xarray as xr

from pystac_client import Client
import planetary_computer as pc

WQ_PATH = "water_quality_training_dataset.csv"

df = pd.read_csv(WQ_PATH)
df.columns = [c.strip() for c in df.columns]

# Parse Sample Date robustly (your file looks like day-month-year)
df["Sample Date"] = pd.to_datetime(df["Sample Date"], errors="coerce", dayfirst=True)

# Keep only 2011–2015 (inclusive)
df = df[df["Sample Date"].between("2011-01-01", "2015-12-31")].copy()

# Ensure numeric lat/lon
df["Latitude"]  = pd.to_numeric(df["Latitude"], errors="coerce")
df["Longitude"] = pd.to_numeric(df["Longitude"], errors="coerce")
df = df.dropna(subset=["Latitude", "Longitude", "Sample Date"]).reset_index(drop=True)

print(df.shape)
df.head()
# Out:
# (9319, 6)
#     Latitude  Longitude Sample Date  Total Alkalinity  Electrical Conductance  \
# 0 -28.760833  17.730278  2011-01-02           128.912                   555.0
# 1 -26.861111  28.884722  2011-01-03            74.720                   162.9
# 2 -26.450000  28.085833  2011-01-03            89.254                   573.0
# 3 -27.671111  27.236944  2011-01-03            82.000                   203.6
# 4 -27.356667  27.286389  2011-01-03            56.100                   145.1
#
#    Dissolved Reactive Phosphorus
# 0                           10.0
# 1                          163.0
# 2                           80.0
# 3                          101.0
# 4                          151.0

# %%
STAC_URL = "https://planetarycomputer.microsoft.com/api/stac/v1"
COLLECTION = "deltares-water-availability"

client = Client.open(STAC_URL)

search = client.search(collections=[COLLECTION])
items = list(search.get_items())
print("items found:", len(items))
print("example item ids:", [it.id for it in items[:5]])
# Out:
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# items found: 5
# example item ids: ['CHIRPS', 'NLDAS', 'EOBS', 'BOM', 'ERA5']

# %%
def choose_item(items, keyword="era5"):
    kw = keyword.lower()
    for it in items:
        blob = json.dumps(it.to_dict()).lower()
        if kw in blob:
            return it
    return items[0]

item = choose_item(items, keyword="era5")
item = pc.sign(item)  # IMPORTANT: signs the assets for access

print("chosen item:", item.id)
print("assets:", list(item.assets.keys()))
# Out:
# chosen item: ERA5
# assets: ['data', 'index']

# %%
index_href = item.assets["index"].href  # signed already by pc.sign(item)

with fsspec.open(index_href, "r") as f:
    ref = json.load(f)

print("ref keys:", ref.keys())
print("refs entries:", len(ref.get("refs", {})))
# Out:
# ref keys: dict_keys(['version', 'templates', 'refs'])
# refs entries: 223612

# %%
def sign_kerchunk_refs(ref_dict):
    refs = ref_dict.get("refs", {})
    for k, v in refs.items():
        # Kerchunk refs often look like: [URL, offset, length]
        if isinstance(v, list) and len(v) >= 1 and isinstance(v[0], str) and v[0].startswith("https://"):
            refs[k][0] = pc.sign(v[0])
        # Sometimes refs can be plain strings
        elif isinstance(v, str) and v.startswith("https://"):
            refs[k] = pc.sign(v)
    return ref_dict

ref = sign_kerchunk_refs(ref)

# %%
def make_ref_mapper(ref_dict):
    # Try the common modern signature first
    try:
        fs = fsspec.filesystem(
            "reference",
            fo=ref_dict,
            remote_protocol="https",
            target_protocol="https",
        )
        return fs.get_mapper("")
    except TypeError:
        # Fallback for older signatures
        fs = fsspec.filesystem(
            "reference",
            fo=ref_dict,
            target_protocol="https",
        )
        return fs.get_mapper("")

mapper = make_ref_mapper(ref)
print("mapper ready")
# Out:
# mapper ready

# %%
try:
    ds = xr.open_zarr(mapper, consolidated=False)
except Exception as e:
    print("open_zarr failed:", repr(e))
    # xarray>=2025 sometimes expects the generic "store" engine in some setups
    ds = xr.open_dataset(mapper, engine="store")

print(ds)
print("dims:", ds.dims)
print("data_vars (first 20):", list(ds.data_vars)[:20])
# Out:
# open_zarr failed: TypeError("ReferenceNotReachable.__init__() missing 1 required positional argument: 'target'")
# ---------------------------------------------------------------------------
# ClientResponseError                       Traceback (most recent call last)
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/fsspec/asyn.py:244, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     243 try:
# --> 244     return await asyncio.wait_for(coro, timeout=timeout), i
#     245 except Exception as e:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/asyncio/tasks.py:408, in wait_for(fut, timeout)
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/fsspec/implementations/http.py:247, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     246     out = await r.read()
# --> 247     self._raise_not_found_for_status(r, url)
#     248 return out
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/fsspec/implementations/http.py:230, in HTTPFileSystem._raise_not_found_for_status(self, response, url)
#     229     raise FileNotFoundError(url)
# --> 230 response.raise_for_status()
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/aiohttp/client_reqrep.py:636, in ClientResponse.raise_for_status(self)
#     634     self.release()
# --> 636 raise ClientResponseError(
#     637     self.request_info,
#     638     self.history,
#     639     status=self.status,
#     640     message=self.reason,
#     641     headers=self.headers,
#     642 )
#
# ClientResponseError: 409, message='Public access is not permitted on this storage account.', url='https://deltaresreservoirssa.blob.core.windows.net/reservoirs/v2021.12/reservoirs_ERA5.nc'
#
# The above exception was the direct cause of the following exception:
#
# ReferenceNotReachable                     Traceback (most recent call last)
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/conventions.py:404, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     403 try:
# --> 404     new_vars[k] = decode_cf_variable(
#     405         k,
#     406         v,
#     407         concat_characters=_item_or_default(concat_characters, k, True),
#     408         mask_and_scale=_item_or_default(mask_and_scale, k, True),
#     409         decode_times=_item_or_default(decode_times, k, True),
#     410         stack_char_dim=stack_char_dim,
#     411         use_cftime=_item_or_default(use_cftime, k, None),
#     412         decode_timedelta=_item_or_default(decode_timedelta, k, None),
#     413     )
#     414 except Exception as e:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/conventions.py:239, in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     230         raise TypeError(
#     231             "Usage of 'use_cftime' as a kwarg is not allowed "
#     232             "if a 'CFDatetimeCoder' instance is passed to "
#    (...)
#     237             "    ds = xr.open_dataset(decode_times=time_coder)\n",
#     238         )
# --> 239     var = decode_times.decode(var, name=name)
#     241 if decode_endianness and not var.dtype.isnative:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/coding/times.py:1391, in CFDatetimeCoder.decode(self, variable, name)
#    1390 calendar = pop_to(attrs, encoding, "calendar")
# -> 1391 dtype = _decode_cf_datetime_dtype(
#    1392     data, units, calendar, self.use_cftime, self.time_unit
#    1393 )
#    1394 transform = partial(
#    1395     decode_cf_datetime,
#    1396     units=units,
#    (...)
#    1399     time_unit=self.time_unit,
#    1400 )
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/coding/times.py:333, in _decode_cf_datetime_dtype(data, units, calendar, use_cftime, time_unit)
#     331 values = indexing.ImplicitToExplicitIndexingAdapter(indexing.as_indexable(data))
#     332 example_value = np.concatenate(
# --> 333     [to_numpy(first_n_items(values, 1)), to_numpy(last_item(values))]
#     334 )
#     336 try:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/core/formatting.py:98, in first_n_items(array, n_desired)
#      97     array = array._data
# ---> 98 return ravel(to_duck_array(array))[:n_desired]
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/namedarray/pycompat.py:143, in to_duck_array(data, **kwargs)
#     142 if isinstance(data, ExplicitlyIndexed | ImplicitToExplicitIndexingAdapter):
# --> 143     return data.get_duck_array()  # type: ignore[no-untyped-call, no-any-return]
#     144 elif is_duck_array(data):
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/core/indexing.py:580, in ImplicitToExplicitIndexingAdapter.get_duck_array(self)
#     579 def get_duck_array(self):
# --> 580     return self.array.get_duck_array()
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/coding/common.py:76, in _ElementwiseFunctionArray.get_duck_array(self)
#      75 def get_duck_array(self):
# ---> 76     return self.func(self.array.get_duck_array())
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/core/indexing.py:654, in LazilyIndexedArray.get_duck_array(self)
#     651 else:
#     652     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     653     # it may wrap a BackendArray so use its __getitem__
# --> 654     array = self.array[self.key]
#     656 # self.array[self.key] is now a numpy array when
#     657 # self.array is a BackendArray subclass
#     658 # and self.key is BasicIndexer((slice(None, None, None),))
#     659 # so we need the explicit check for ExplicitlyIndexed
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/zarr.py:224, in ZarrArrayWrapper.__getitem__(self, key)
#     223     method = self._oindex
# --> 224 return indexing.explicit_indexing_adapter(
#     225     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     226 )
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/core/indexing.py:1023, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1022 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1023 result = raw_indexing_method(raw_key.tuple)
#    1024 if numpy_indices.tuple:
#    1025     # index the loaded duck array
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/zarr.py:214, in ZarrArrayWrapper._getitem(self, key)
#     213 def _getitem(self, key):
# --> 214     return self._array[key]
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/core.py:797, in Array.__getitem__(self, selection)
#     796 else:
# --> 797     result = self.get_basic_selection(pure_selection, fields=fields)
#     798 return result
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/core.py:923, in Array.get_basic_selection(self, selection, out, fields)
#     922 else:
# --> 923     return self._get_basic_selection_nd(selection=selection, out=out, fields=fields)
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/core.py:965, in Array._get_basic_selection_nd(self, selection, out, fields)
#     963 indexer = BasicIndexer(selection, self)
# --> 965 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/core.py:1340, in Array._get_selection(self, indexer, out, fields)
#    1339     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1340     self._chunk_getitems(
#    1341         lchunk_coords,
#    1342         lchunk_selection,
#    1343         out,
#    1344         lout_selection,
#    1345         drop_axes=indexer.drop_axes,
#    1346         fields=fields,
#    1347     )
#    1348 if out.shape:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/core.py:2181, in Array._chunk_getitems(self, lchunk_coords, lchunk_selection, out, lout_selection, drop_axes, fields)
#    2180         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2181     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2183 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/zarr/storage.py:1435, in FSStore.getitems(self, keys, contexts)
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#
# ReferenceNotReachable: Reference "time/0" failed to fetch target ['https://deltaresreservoirssa.blob.core.windows.net/reservoirs/v2021.12/reservoirs_ERA5.nc', 4922, 4096]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 try:
# ----> 2     ds = xr.open_zarr(mapper, consolidated=False)
#       3 except Exception as e:
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/zarr.py:1505, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1495 backend_kwargs = {
#    1496     "synchronizer": synchronizer,
#    1497     "consolidated": consolidated,
#    (...)
#    1502     "zarr_format": zarr_format,
#    1503 }
# -> 1505 ds = open_dataset(
#    1506     filename_or_obj=store,
#    1507     group=group,
#    1508     decode_cf=decode_cf,
#    1509     mask_and_scale=mask_and_scale,
#    1510     decode_times=decode_times,
#    1511     concat_characters=concat_characters,
#    1512     decode_coords=decode_coords,
#    1513     engine="zarr",
#    1514     chunks=chunks,
#    1515     drop_variables=drop_variables,
#    1516     chunked_array_type=chunked_array_type,
#    1517     from_array_kwargs=from_array_kwargs,
#    1518     backend_kwargs=backend_kwargs,
#    1519     decode_timedelta=decode_timedelta,
#    1520     use_cftime=use_cftime,
#    1521     zarr_version=zarr_version,
#    1522     use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#    1523 )
#    1524 return ds
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/zarr.py:1595, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask, cache_members)
#    1594 with close_on_error(store):
# -> 1595     ds = store_entrypoint.open_dataset(
#    1596         store,
#    1597         mask_and_scale=mask_and_scale,
#    1598         decode_times=decode_times,
#    1599         concat_characters=concat_characters,
#    1600         decode_coords=decode_coords,
#    1601         drop_variables=drop_variables,
#    1602         use_cftime=use_cftime,
#    1603         decode_timedelta=decode_timedelta,
#    1604     )
#    1605 return ds
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/store.py:47, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      45 encoding = filename_or_obj.get_encoding()
# ---> 47 vars, attrs, coord_names = conventions.decode_cf_variables(
#      48     vars,
#      49     attrs,
#      50     mask_and_scale=mask_and_scale,
#      51     decode_times=decode_times,
#      52     concat_characters=concat_characters,
#      53     decode_coords=decode_coords,
#      54     drop_variables=drop_variables,
#      55     use_cftime=use_cftime,
#      56     decode_timedelta=decode_timedelta,
#      57 )
#      59 ds = Dataset(vars, attrs=attrs)
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/conventions.py:415, in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     414 except Exception as e:
# --> 415     raise type(e)(f"Failed to decode variable {k!r}: {e}") from e
#     416 if decode_coords in [True, "coordinates", "all"]:
#
# TypeError: ReferenceNotReachable.__init__() missing 1 required positional argument: 'target'
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 6
#       4     print("open_zarr failed:", repr(e))
#       5     # xarray>=2025 sometimes expects the generic "store" engine in some setups
# ----> 6     ds = xr.open_dataset(mapper, engine="store")
#       8 print(ds)
#       9 print("dims:", ds.dims)
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/api.py:687, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     675 decoders = _resolve_decoders_kwargs(
#     676     decode_cf,
#     677     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     683     decode_coords=decode_coords,
#     684 )
#     686 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 687 backend_ds = backend.open_dataset(
#     688     filename_or_obj,
#     689     drop_variables=drop_variables,
#     690     **decoders,
#     691     **kwargs,
#     692 )
#     693 ds = _dataset_from_backend_dataset(
#     694     backend_ds,
#     695     filename_or_obj,
#    (...)
#     705     **kwargs,
#     706 )
#     707 return ds
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/backends/store.py:42, in StoreBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta)
#      30 def open_dataset(
#      31     self,
#      32     filename_or_obj: str | os.PathLike[Any] | ReadBuffer | AbstractDataStore,
#    (...)
#      40     decode_timedelta=None,
#      41 ) -> Dataset:
# ---> 42     assert isinstance(filename_or_obj, AbstractDataStore)
#      44     vars, attrs = filename_or_obj.load()
#      45     encoding = filename_or_obj.get_encoding()
#
# AssertionError:
