# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# ====================== FEATURE ENGINEERING ======================
def add_features(data):
    data = data.copy()
    data['Sample Date'] = pd.to_datetime(data['Sample Date'], format='%d-%m-%Y', errors='coerce')
    data = data.dropna(subset=['Sample Date'])
    
    data['lat'] = data['Latitude']
    data['lon'] = data['Longitude']
    
    for angle, prefix in [(data['lat'], 'lat'), (data['lon'], 'lon')]:
        rad = np.radians(angle)
        for k in [1, 2, 3, 4]:
            data[f'{prefix}_sin_{k}'] = np.sin(k * rad)
            data[f'{prefix}_cos_{k}'] = np.cos(k * rad)
    
    data['year'] = data['Sample Date'].dt.year.astype(float)
    data['year_norm'] = (data['year'] - 2011) / 4.0
    data['month'] = data['Sample Date'].dt.month.astype(float)
    data['doy']   = data['Sample Date'].dt.dayofyear.astype(float)
    
    data['doy_sin_365'] = np.sin(2 * np.pi * data['doy'] / 365.25)
    data['doy_cos_365'] = np.cos(2 * np.pi * data['doy'] / 365.25)
    data['month_sin_12'] = np.sin(2 * np.pi * data['month'] / 12)
    data['month_cos_12'] = np.cos(2 * np.pi * data['month'] / 12)
    
    for period, label in [(182.625, '182_6'), (91.3125, '91_3'), (30.4375, '30_4')]:
        data[f'doy_sin_{label}'] = np.sin(2 * np.pi * data['doy'] / period)
        data[f'doy_cos_{label}'] = np.cos(2 * np.pi * data['doy'] / period)
    
    data['lat_doy_sin'] = data['lat_sin_1'] * data['doy_sin_365']
    data['lon_doy_sin'] = data['lon_sin_1'] * data['doy_sin_365']
    data['lat_year']    = data['lat'] * data['year_norm']
    data['lon_year']    = data['lon'] * data['year_norm']
    
    return data

# ====================== LOAD & MERGE TRAINING DATA ======================
print("=== Loading & merging training data ===")

df_target = pd.read_csv('water_quality_training_dataset.csv')
df_terra = pd.read_csv('terraclimate_features_training.csv')

# All Landsat data
df_landsat1 = pd.read_csv('landsat_features_training.csv')
df_landsat2 = pd.read_csv('landsat_features_2000_2006_200_samples.csv')
df_landsat3 = pd.read_csv('landsat_features_2015_2023_200_samples.csv')
df_landsat = pd.concat([df_landsat1, df_landsat2, df_landsat3], ignore_index=True)

# Deltares data
df_deltares = pd.read_csv('deltares_water_2010_2015_200_samples.csv')

df_train = df_target.merge(df_terra, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
df_train = df_train.merge(df_landsat, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
df_train = df_train.merge(df_deltares, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
df_train = add_features(df_train)

# ====================== FEATURE LIST ======================
raw_features = ['pet', 'nir', 'green', 'swir16', 'swir22', 'NDMI', 'MNDWI',
                'P', 'ETa', 'PET', 'Melt', 'Snow', 'Temp', 'P_res', 'S_res', 
                'Ea_res', 'Qin_res', 'FracFull', 'Qout_res']

engineered = [c for c in df_train.columns if any(x in c for x in [
    'sin', 'cos', 'year', 'doy_', 'month_', 'lat_', 'lon_'
])]

features = raw_features + engineered

print(f"Using {len(features)} features")

# ====================== PREPARE DATA ======================
df_train = df_train.fillna(df_train.median(numeric_only=True))  # Use median impute as in benchmark
X = df_train[features]
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

targets = {
    'TA':  df_train['Total Alkalinity'],
    'EC':  df_train['Electrical Conductance'],
    'DRP': df_train['Dissolved Reactive Phosphorus']
}

# ====================== XGBoost & LightGBM Params ======================
xgb_params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'learning_rate': 0.01,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'tree_method': 'hist',
    'seed': 42
}

lgb_params = {
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'max_depth': 5,
    'num_leaves': 31,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'n_jobs': -1,
    'verbosity': -1,
    'random_state': 42,
    'force_col_wise': True
}

# ====================== TRAINING (5-fold CV) ======================
kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = {}

for name, y in targets.items():
    print(f"\n=== Training {name} ===")
    oof = np.zeros(len(y))
    xgb_list = []
    lgb_list = []
    
    for fold, (tr_idx, val_idx) in enumerate(kf.split(X_scaled)):
        X_tr, X_val = X_scaled[tr_idx], X_scaled[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]
        
        # XGBoost
        dtrain = xgb.DMatrix(X_tr, label=y_tr)
        dval = xgb.DMatrix(X_val, label=y_val)
        evals = [(dval, 'eval')]
        xgb_booster = xgb.train(
            xgb_params,
            dtrain,
            num_boost_round=1000,
            evals=evals,
            early_stopping_rounds=50,
            verbose_eval=100
        )
        xgb_list.append(xgb_booster)
        
        # LightGBM
        lgb_model = lgb.LGBMRegressor(**lgb_params)
        lgb_model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(50), lgb.log_evaluation(period=100)]
        )
        lgb_list.append(lgb_model)
        
        # OOF for blend
        xgb_pred = xgb_booster.predict(dval)
        lgb_pred = lgb_model.predict(X_val)
        blend_pred = (xgb_pred + lgb_pred) / 2
        oof[val_idx] = blend_pred
    
    r2 = r2_score(y, oof)
    rmse = np.sqrt(mean_squared_error(y, oof))
    print(f"{name}  CV R² = {r2:.4f}   RMSE = {rmse:.2f}")
    
    models[name] = (xgb_list, lgb_list)

# ====================== SUBMISSION ======================
print("\n=== Generating submission ===")
sub = pd.read_csv('submission_template.csv')

df_terra_val = pd.read_csv('terraclimate_features_validation.csv')
df_landsat_val = pd.read_csv('landsat_features_validation.csv')

sub = sub.merge(df_terra_val, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
sub = sub.merge(df_landsat_val, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
sub = add_features(sub)

# Add missing Deltares columns as 0
deltares_cols = ['P', 'ETa', 'PET', 'Melt', 'Snow', 'Temp', 'P_res', 'S_res', 
                 'Ea_res', 'Qin_res', 'FracFull', 'Qout_res']
for col in deltares_cols:
    if col not in sub.columns:
        sub[col] = 0

sub = sub.fillna(sub.median(numeric_only=True))  # Median impute for sub

sub_X = sub[features]
sub_X_scaled = scaler.transform(sub_X)
dsub = xgb.DMatrix(sub_X_scaled)

def blend_predict(xgb_models, lgb_models, X, dX):
    xgb_preds = np.mean([m.predict(dX) for m in xgb_models], axis=0)
    lgb_preds = np.mean([m.predict(X) for m in lgb_models], axis=0)
    return (xgb_preds + lgb_preds) / 2

sub['Total Alkalinity']              = blend_predict(models['TA'][0], models['TA'][1], sub_X_scaled, dsub)
sub['Electrical Conductance']        = blend_predict(models['EC'][0], models['EC'][1], sub_X_scaled, dsub)
sub['Dissolved Reactive Phosphorus'] = blend_predict(models['DRP'][0], models['DRP'][1], sub_X_scaled, dsub)

# Ensemble with previous submission
previous_sub = pd.read_csv('submission_larger_landsat_deltares_xgb.csv')
previous_sub['Sample Date'] = pd.to_datetime(previous_sub['Sample Date'])
sub['Sample Date'] = pd.to_datetime(sub['Sample Date'])
sub = sub.merge(previous_sub, on=['Latitude', 'Longitude', 'Sample Date'], how='left', suffixes=('', '_prev'))

sub['Total Alkalinity'] = (sub['Total Alkalinity'] + sub['Total Alkalinity_prev']) / 2
sub['Electrical Conductance'] = (sub['Electrical Conductance'] + sub['Electrical Conductance_prev']) / 2
sub['Dissolved Reactive Phosphorus'] = (sub['Dissolved Reactive Phosphorus'] + sub['Dissolved Reactive Phosphorus_prev']) / 2

sub = sub.drop(columns=[col for col in sub.columns if '_prev' in col])

# Clip
sub['Total Alkalinity'] = sub['Total Alkalinity'].clip(5, 400)
sub['Electrical Conductance'] = sub['Electrical Conductance'].clip(30, 2200)
sub['Dissolved Reactive Phosphorus'] = sub['Dissolved Reactive Phosphorus'].clip(0.5, 250)

final_sub = sub[['Latitude', 'Longitude', 'Sample Date',
                 'Total Alkalinity', 'Electrical Conductance', 'Dissolved Reactive Phosphorus']]

final_sub.to_csv('submission_all_files_blend_ensemble.csv', index=False)
print("✅ Saved → submission_all_files_blend_ensemble.csv")
# Out:
# === Loading & merging training data ===
# Using 51 features
#
# === Training TA ===
# [0]	eval-rmse:75.40784
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1243: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1437: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# [100]	eval-rmse:50.71654
# [200]	eval-rmse:43.12077
# [300]	eval-rmse:39.76674
# [400]	eval-rmse:37.85961
# [500]	eval-rmse:36.59038
# [600]	eval-rmse:35.66607
# [700]	eval-rmse:35.02376
# [800]	eval-rmse:34.46180
# [900]	eval-rmse:34.00400
# [999]	eval-rmse:33.59736
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 50.9959
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 50.9959
# [0]	eval-rmse:73.62113
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:48.30414
# [200]	eval-rmse:40.62315
# [300]	eval-rmse:37.45357
# [400]	eval-rmse:35.50922
# [500]	eval-rmse:34.26682
# [600]	eval-rmse:33.38269
# [700]	eval-rmse:32.69624
# [800]	eval-rmse:32.08673
# [900]	eval-rmse:31.62606
# [999]	eval-rmse:31.18796
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 48.4462
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 48.4462
# [0]	eval-rmse:74.54903
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:49.71590
# [200]	eval-rmse:42.12703
# [300]	eval-rmse:39.02059
# [400]	eval-rmse:37.19121
# [500]	eval-rmse:35.97041
# [600]	eval-rmse:35.05425
# [700]	eval-rmse:34.45601
# [800]	eval-rmse:33.86692
# [900]	eval-rmse:33.35151
# [999]	eval-rmse:32.96896
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 49.8616
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 49.8616
# [0]	eval-rmse:72.84561
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:47.89314
# [200]	eval-rmse:40.55698
# [300]	eval-rmse:37.33193
# [400]	eval-rmse:35.66243
# [500]	eval-rmse:34.47653
# [600]	eval-rmse:33.69140
# [700]	eval-rmse:33.09480
# [800]	eval-rmse:32.56954
# [900]	eval-rmse:32.19197
# [999]	eval-rmse:31.82627
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 48.0973
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 48.0973
# [0]	eval-rmse:74.75688
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:48.56027
# [200]	eval-rmse:40.47211
# [300]	eval-rmse:36.94017
# [400]	eval-rmse:34.87781
# [500]	eval-rmse:33.59383
# [600]	eval-rmse:32.70850
# [700]	eval-rmse:31.99897
# [800]	eval-rmse:31.42590
# [900]	eval-rmse:30.91506
# [999]	eval-rmse:30.48934
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 49.2545
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 49.2545
# TA  CV R² = 0.7322   RMSE = 38.65
#
# === Training EC ===
# [0]	eval-rmse:343.45745
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:225.27537
# [200]	eval-rmse:184.65661
# [300]	eval-rmse:168.54597
# [400]	eval-rmse:159.45245
# [500]	eval-rmse:153.19408
# [600]	eval-rmse:149.06297
# [700]	eval-rmse:145.73066
# [800]	eval-rmse:143.27527
# [900]	eval-rmse:141.30062
# [999]	eval-rmse:139.43349
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 224.799
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 224.799
# [0]	eval-rmse:334.38955
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:215.53846
# [200]	eval-rmse:177.04413
# [300]	eval-rmse:163.26632
# [400]	eval-rmse:156.10401
# [500]	eval-rmse:151.32356
# [600]	eval-rmse:147.50258
# [700]	eval-rmse:144.55556
# [800]	eval-rmse:142.30647
# [900]	eval-rmse:140.43940
# [999]	eval-rmse:138.97762
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 215.83
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 215.83
# [0]	eval-rmse:337.48516
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:217.10914
# [200]	eval-rmse:179.60647
# [300]	eval-rmse:164.81126
# [400]	eval-rmse:156.74623
# [500]	eval-rmse:150.78804
# [600]	eval-rmse:146.65211
# [700]	eval-rmse:143.40288
# [800]	eval-rmse:141.01427
# [900]	eval-rmse:138.93816
# [999]	eval-rmse:137.30936
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 217.992
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 217.992
# [0]	eval-rmse:335.96358
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:214.08418
# [200]	eval-rmse:173.09483
# [300]	eval-rmse:158.25533
# [400]	eval-rmse:150.17267
# [500]	eval-rmse:145.04581
# [600]	eval-rmse:141.36309
# [700]	eval-rmse:138.49770
# [800]	eval-rmse:136.10506
# [900]	eval-rmse:134.18208
# [999]	eval-rmse:132.93205
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 215.401
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 215.401
# [0]	eval-rmse:347.36667
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:226.79701
# [200]	eval-rmse:185.41311
# [300]	eval-rmse:167.61726
# [400]	eval-rmse:158.28371
# [500]	eval-rmse:152.14566
# [600]	eval-rmse:147.33581
# [700]	eval-rmse:143.78364
# [800]	eval-rmse:140.92437
# [900]	eval-rmse:138.48605
# [999]	eval-rmse:136.93612
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 227.143
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 227.143
# EC  CV R² = 0.7571   RMSE = 168.50
#
# === Training DRP ===
# [0]	eval-rmse:51.58737
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.86000
# [200]	eval-rmse:35.07031
# [300]	eval-rmse:33.41308
# [400]	eval-rmse:32.41286
# [500]	eval-rmse:31.77815
# [600]	eval-rmse:31.31174
# [700]	eval-rmse:30.98824
# [800]	eval-rmse:30.72851
# [900]	eval-rmse:30.53848
# [999]	eval-rmse:30.34057
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 39.0919
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 39.0919
# [0]	eval-rmse:50.98388
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.62699
# [200]	eval-rmse:35.16417
# [300]	eval-rmse:33.50550
# [400]	eval-rmse:32.61772
# [500]	eval-rmse:31.97797
# [600]	eval-rmse:31.52824
# [700]	eval-rmse:31.19335
# [800]	eval-rmse:30.92479
# [900]	eval-rmse:30.71410
# [999]	eval-rmse:30.49990
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 38.5508
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 38.5508
# [0]	eval-rmse:51.59606
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.33929
# [200]	eval-rmse:34.71973
# [300]	eval-rmse:33.15488
# [400]	eval-rmse:32.32624
# [500]	eval-rmse:31.76993
# [600]	eval-rmse:31.39103
# [700]	eval-rmse:31.08391
# [800]	eval-rmse:30.84211
# [900]	eval-rmse:30.64297
# [999]	eval-rmse:30.48088
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 38.3694
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 38.3694
# [0]	eval-rmse:49.11943
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:36.45485
# [200]	eval-rmse:32.90114
# [300]	eval-rmse:31.35315
# [400]	eval-rmse:30.48301
# [500]	eval-rmse:29.89155
# [600]	eval-rmse:29.49196
# [700]	eval-rmse:29.20323
# [800]	eval-rmse:28.97084
# [900]	eval-rmse:28.76410
# [999]	eval-rmse:28.61580
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 36.4718
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 36.4718
# [0]	eval-rmse:50.35320
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:37.22659
# [200]	eval-rmse:33.36949
# [300]	eval-rmse:31.74345
# [400]	eval-rmse:30.90771
# [500]	eval-rmse:30.38881
# [600]	eval-rmse:30.05567
# [700]	eval-rmse:29.80797
# [800]	eval-rmse:29.63245
# [900]	eval-rmse:29.48641
# [999]	eval-rmse:29.35495
# Training until validation scores don't improve for 50 rounds
# [100]	valid_0's rmse: 37.3796
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 37.3796
# DRP  CV R² = 0.5838   RMSE = 32.89
#
# === Generating submission ===
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ✅ Saved → submission_all_files_blend_ensemble.csv
