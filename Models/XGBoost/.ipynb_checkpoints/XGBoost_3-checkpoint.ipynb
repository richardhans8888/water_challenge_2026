# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import r2_score, mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# ====================== FEATURE ENGINEERING ======================
def add_features(data):
    data = data.copy()
    data['Sample Date'] = pd.to_datetime(data['Sample Date'], format='%d-%m-%Y', errors='coerce')
    data = data.dropna(subset=['Sample Date'])
    
    data['lat'] = data['Latitude']
    data['lon'] = data['Longitude']
    
    # Trigonometric encoding for lat/lon
    for angle, prefix in [(data['lat'], 'lat'), (data['lon'], 'lon')]:
        rad = np.radians(angle)
        for k in [1, 2, 3, 4]:
            data[f'{prefix}_sin_{k}'] = np.sin(k * rad)
            data[f'{prefix}_cos_{k}'] = np.cos(k * rad)
    
    # Time features
    data['year'] = data['Sample Date'].dt.year.astype(float)
    data['year_norm'] = (data['year'] - 2011) / 4.0
    data['month'] = data['Sample Date'].dt.month.astype(float)
    data['doy']   = data['Sample Date'].dt.dayofyear.astype(float)
    
    # Cyclic encodings
    data['doy_sin_365'] = np.sin(2 * np.pi * data['doy'] / 365.25)
    data['doy_cos_365'] = np.cos(2 * np.pi * data['doy'] / 365.25)
    data['month_sin_12'] = np.sin(2 * np.pi * data['month'] / 12)
    data['month_cos_12'] = np.cos(2 * np.pi * data['month'] / 12)
    
    for period, label in [(182.625, '182_6'), (91.3125, '91_3'), (30.4375, '30_4')]:
        data[f'doy_sin_{label}'] = np.sin(2 * np.pi * data['doy'] / period)
        data[f'doy_cos_{label}'] = np.cos(2 * np.pi * data['doy'] / period)
    
    # Interaction features
    data['lat_doy_sin'] = data['lat_sin_1'] * data['doy_sin_365']
    data['lon_doy_sin'] = data['lon_sin_1'] * data['doy_sin_365']
    data['lat_year']    = data['lat'] * data['year_norm']
    data['lon_year']    = data['lon'] * data['year_norm']
    
    # Landsat band ratios for water quality
    data['turbidity'] = data['nir'] / data['green']
    data['phosphorus_proxy'] = (data['swir16'] - data['nir']) / (data['swir16'] + data['nir'])
    data['conductivity_proxy'] = data['swir22'] / data['swir16']
    data['alkalinity_proxy'] = data['green'] / data['swir22']
    
    return data

# ====================== LOAD & MERGE LARGER TRAINING SET ======================
print("=== Loading & merging larger training data ===")

df_target = pd.read_csv('water_quality_training_dataset.csv')

# Terraclimate
df_terra = pd.read_csv('terraclimate_features_training.csv')

# All Landsat data (main + two extra 200-sample sets)
df_landsat1 = pd.read_csv('landsat_features_training.csv')
df_landsat2 = pd.read_csv('landsat_features_2000_2006_200_samples.csv')
df_landsat3 = pd.read_csv('landsat_features_2015_2023_200_samples.csv')
df_landsat = pd.concat([df_landsat1, df_landsat2, df_landsat3], ignore_index=True)

# Deltares data
df_deltares = pd.read_csv('deltares_water_2010_2015_200_samples.csv')

# Merge everything
df_train = df_target.merge(df_terra, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
df_train = df_train.merge(df_landsat, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
df_train = df_train.merge(df_deltares, on=['Latitude', 'Longitude', 'Sample Date'], how='left')

df_train = add_features(df_train)

# ====================== FEATURE LIST ======================
raw_features = ['pet', 'nir', 'green', 'swir16', 'swir22', 'NDMI', 'MNDWI',
                'P', 'ETa', 'PET', 'Melt', 'Snow', 'Temp', 'P_res', 'S_res', 
                'Ea_res', 'Qin_res', 'FracFull', 'Qout_res', 'turbidity', 'phosphorus_proxy', 'conductivity_proxy', 'alkalinity_proxy']

engineered = [c for c in df_train.columns if any(x in c for x in [
    'sin', 'cos', 'year', 'doy_', 'month_', 'lat_', 'lon_'
])]

features = raw_features + engineered

print(f"Using {len(features)} features (including extra Landsat & Deltares samples)")

# ====================== PREPARE DATA ======================
df_train = df_train.fillna(df_train.median(numeric_only=True))
X = df_train[features]
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

targets = {
    'TA':  df_train['Total Alkalinity'],
    'EC':  df_train['Electrical Conductance'],
    'DRP': df_train['Dissolved Reactive Phosphorus']
}

# ====================== TRAINING (5-fold CV) ======================
xgb_params = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'learning_rate': 0.01,
    'max_depth': 5,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'tree_method': 'hist',
    'seed': 42
}

lgb_params = {
    'objective': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.01,
    'max_depth': 5,
    'num_leaves': 31,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'n_jobs': -1,
    'verbosity': -1,
    'random_state': 42,
    'force_col_wise': True
}

kf = KFold(n_splits=5, shuffle=True, random_state=42)
models = {}

for name, y in targets.items():
    print(f"\n=== Training {name} ===")
    oof = np.zeros(len(y))
    xgb_list = []
    lgb_list = []
    
    for fold, (tr_idx, val_idx) in enumerate(kf.split(X_scaled)):
        X_tr, X_val = X_scaled[tr_idx], X_scaled[val_idx]
        y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]
        
        # XGBoost
        dtrain = xgb.DMatrix(X_tr, label=y_tr)
        dval = xgb.DMatrix(X_val, label=y_val)
        evals = [(dval, 'eval')]
        booster = xgb.train(
            xgb_params,
            dtrain,
            num_boost_round=1000,
            evals=evals,
            early_stopping_rounds=50,
            verbose_eval=100
        )
        xgb_list.append(booster)
        
        # LightGBM
        lgb_model = lgb.LGBMRegressor(**lgb_params)
        lgb_model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)],
            callbacks=[lgb.early_stopping(50)]
        )
        lgb_list.append(lgb_model)
        
        # OOF for blend
        xgb_pred = booster.predict(dval)
        lgb_pred = lgb_model.predict(X_val)
        blend_pred = (xgb_pred + lgb_pred) / 2
        oof[val_idx] = blend_pred
    
    r2 = r2_score(y, oof)
    rmse = np.sqrt(mean_squared_error(y, oof))
    print(f"{name}  CV R² = {r2:.4f}   RMSE = {rmse:.2f}")
    
    models[name] = (xgb_list, lgb_list)

# ====================== SUBMISSION ======================
print("\n=== Generating submission ===")
sub = pd.read_csv('submission_template.csv')

df_terra_val = pd.read_csv('terraclimate_features_validation.csv')
df_landsat_val = pd.read_csv('landsat_features_validation.csv')

sub = sub.merge(df_terra_val, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
sub = sub.merge(df_landsat_val, on=['Latitude', 'Longitude', 'Sample Date'], how='left')
sub = add_features(sub)

# Add missing Deltares columns as 0
deltares_cols = ['P', 'ETa', 'PET', 'Melt', 'Snow', 'Temp', 'P_res', 'S_res', 
                 'Ea_res', 'Qin_res', 'FracFull', 'Qout_res']
for col in deltares_cols:
    if col not in sub.columns:
        sub[col] = 0

sub = sub.fillna(sub.median(numeric_only=True))

sub_X = sub[features]
sub_X_scaled = scaler.transform(sub_X)
dsub = xgb.DMatrix(sub_X_scaled)

def blend_predict(xgb_models, lgb_models, X, dX):
    xgb_preds = np.mean([m.predict(dX) for m in xgb_models], axis=0)
    lgb_preds = np.mean([m.predict(X) for m in lgb_models], axis=0)
    return (xgb_preds + lgb_preds) / 2

sub['Total Alkalinity']              = blend_predict(models['TA'][0], models['TA'][1], sub_X_scaled, dsub)
sub['Electrical Conductance']        = blend_predict(models['EC'][0], models['EC'][1], sub_X_scaled, dsub)
sub['Dissolved Reactive Phosphorus'] = blend_predict(models['DRP'][0], models['DRP'][1], sub_X_scaled, dsub)

# Ensemble with previous submission
previous_sub = pd.read_csv('submission_larger_landsat_deltares_xgb.csv')
previous_sub['Sample Date'] = pd.to_datetime(previous_sub['Sample Date'])
sub['Sample Date'] = pd.to_datetime(sub['Sample Date'])
sub = sub.merge(previous_sub, on=['Latitude', 'Longitude', 'Sample Date'], how='left', suffixes=('', '_prev'))

sub['Total Alkalinity'] = (sub['Total Alkalinity'] + sub['Total Alkalinity_prev']) / 2
sub['Electrical Conductance'] = (sub['Electrical Conductance'] + sub['Electrical Conductance_prev']) / 2
sub['Dissolved Reactive Phosphorus'] = (sub['Dissolved Reactive Phosphorus'] + sub['Dissolved Reactive Phosphorus_prev']) / 2

# Drop prev columns
sub = sub.drop(columns=[c for c in sub.columns if '_prev' in c])

# Clipping (same as your best model)
sub['Total Alkalinity']              = sub['Total Alkalinity'].clip(5, 400)
sub['Electrical Conductance']        = sub['Electrical Conductance'].clip(30, 2200)
sub['Dissolved Reactive Phosphorus'] = sub['Dissolved Reactive Phosphorus'].clip(0.5, 250)

final_sub = sub[['Latitude', 'Longitude', 'Sample Date',
                 'Total Alkalinity', 'Electrical Conductance', 'Dissolved Reactive Phosphorus']]

final_sub.to_csv('submission_deep_blend_fixed.csv', index=False)
print("✅ Saved → submission_deep_blend_fixed.csv")
print("Upload this file and check the leaderboard!")
# Out:
# === Loading & merging larger training data ===
# Using 55 features (including extra Landsat & Deltares samples)
#
# === Training TA ===
# [0]	eval-rmse:75.41044
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1243: RuntimeWarning: All-NaN slice encountered
#   return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/numpy/lib/_nanfunctions_impl.py:1437: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# [100]	eval-rmse:50.66815
# [200]	eval-rmse:43.19289
# [300]	eval-rmse:39.80039
# [400]	eval-rmse:37.84098
# [500]	eval-rmse:36.51467
# [600]	eval-rmse:35.64682
# [700]	eval-rmse:34.96965
# [800]	eval-rmse:34.42758
# [900]	eval-rmse:33.95778
# [999]	eval-rmse:33.55249
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 50.9781
# [0]	eval-rmse:73.62293
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:48.29222
# [200]	eval-rmse:40.65719
# [300]	eval-rmse:37.46031
# [400]	eval-rmse:35.51862
# [500]	eval-rmse:34.15663
# [600]	eval-rmse:33.27379
# [700]	eval-rmse:32.62773
# [800]	eval-rmse:32.01555
# [900]	eval-rmse:31.49562
# [999]	eval-rmse:31.07320
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 48.4205
# [0]	eval-rmse:74.55467
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:49.76540
# [200]	eval-rmse:42.35265
# [300]	eval-rmse:39.29023
# [400]	eval-rmse:37.43611
# [500]	eval-rmse:36.21120
# [600]	eval-rmse:35.29403
# [700]	eval-rmse:34.64325
# [800]	eval-rmse:34.02697
# [900]	eval-rmse:33.54938
# [999]	eval-rmse:33.21334
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 49.8624
# [0]	eval-rmse:72.85061
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:47.96161
# [200]	eval-rmse:40.88061
# [300]	eval-rmse:37.77719
# [400]	eval-rmse:36.07772
# [500]	eval-rmse:34.98104
# [600]	eval-rmse:34.18198
# [700]	eval-rmse:33.58011
# [800]	eval-rmse:33.14219
# [900]	eval-rmse:32.77612
# [999]	eval-rmse:32.41510
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 48.256
# [0]	eval-rmse:74.76116
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:48.65604
# [200]	eval-rmse:40.52199
# [300]	eval-rmse:36.89024
# [400]	eval-rmse:34.78741
# [500]	eval-rmse:33.57222
# [600]	eval-rmse:32.69539
# [700]	eval-rmse:31.99615
# [800]	eval-rmse:31.38706
# [900]	eval-rmse:30.87750
# [999]	eval-rmse:30.44086
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 49.2402
# TA  CV R² = 0.7313   RMSE = 38.71
#
# === Training EC ===
# [0]	eval-rmse:343.45503
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:225.30667
# [200]	eval-rmse:185.14000
# [300]	eval-rmse:168.95827
# [400]	eval-rmse:159.64468
# [500]	eval-rmse:153.05954
# [600]	eval-rmse:148.84521
# [700]	eval-rmse:145.71823
# [800]	eval-rmse:143.28402
# [900]	eval-rmse:141.15943
# [999]	eval-rmse:139.29833
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 224.475
# [0]	eval-rmse:334.40745
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:216.44744
# [200]	eval-rmse:178.00313
# [300]	eval-rmse:163.87740
# [400]	eval-rmse:156.35539
# [500]	eval-rmse:151.68847
# [600]	eval-rmse:147.56406
# [700]	eval-rmse:144.53206
# [800]	eval-rmse:142.08186
# [900]	eval-rmse:140.22585
# [999]	eval-rmse:138.60184
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 216.391
# [0]	eval-rmse:337.48325
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:217.78825
# [200]	eval-rmse:179.89935
# [300]	eval-rmse:164.80757
# [400]	eval-rmse:156.84857
# [500]	eval-rmse:150.73771
# [600]	eval-rmse:146.38268
# [700]	eval-rmse:143.13901
# [800]	eval-rmse:140.61920
# [900]	eval-rmse:138.42668
# [999]	eval-rmse:136.82259
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 218.216
# [0]	eval-rmse:335.97475
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:214.18293
# [200]	eval-rmse:173.13953
# [300]	eval-rmse:158.15990
# [400]	eval-rmse:149.89438
# [500]	eval-rmse:144.69429
# [600]	eval-rmse:141.11750
# [700]	eval-rmse:138.56462
# [800]	eval-rmse:136.29408
# [900]	eval-rmse:134.67378
# [999]	eval-rmse:133.38499
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 216.554
# [0]	eval-rmse:347.36904
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:227.80132
# [200]	eval-rmse:185.93927
# [300]	eval-rmse:168.15817
# [400]	eval-rmse:158.31905
# [500]	eval-rmse:152.24323
# [600]	eval-rmse:147.60958
# [700]	eval-rmse:144.46360
# [800]	eval-rmse:141.54712
# [900]	eval-rmse:139.64755
# [999]	eval-rmse:137.95484
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 227.92
# EC  CV R² = 0.7563   RMSE = 168.79
#
# === Training DRP ===
# [0]	eval-rmse:51.58580
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.85626
# [200]	eval-rmse:35.00410
# [300]	eval-rmse:33.39048
# [400]	eval-rmse:32.33416
# [500]	eval-rmse:31.67634
# [600]	eval-rmse:31.24750
# [700]	eval-rmse:30.92284
# [800]	eval-rmse:30.63632
# [900]	eval-rmse:30.43248
# [999]	eval-rmse:30.24330
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 38.9714
# [0]	eval-rmse:50.98312
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.61730
# [200]	eval-rmse:35.13750
# [300]	eval-rmse:33.47766
# [400]	eval-rmse:32.55839
# [500]	eval-rmse:31.88158
# [600]	eval-rmse:31.46102
# [700]	eval-rmse:31.12539
# [800]	eval-rmse:30.85881
# [900]	eval-rmse:30.66025
# [999]	eval-rmse:30.44376
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 38.6022
# [0]	eval-rmse:51.59365
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:38.32977
# [200]	eval-rmse:34.65740
# [300]	eval-rmse:33.05407
# [400]	eval-rmse:32.14296
# [500]	eval-rmse:31.55483
# [600]	eval-rmse:31.17034
# [700]	eval-rmse:30.84295
# [800]	eval-rmse:30.59251
# [900]	eval-rmse:30.40247
# [999]	eval-rmse:30.26832
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 38.3738
# [0]	eval-rmse:49.11439
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:36.40373
# [200]	eval-rmse:32.84443
# [300]	eval-rmse:31.34504
# [400]	eval-rmse:30.45662
# [500]	eval-rmse:29.78612
# [600]	eval-rmse:29.45269
# [700]	eval-rmse:29.18259
# [800]	eval-rmse:28.92890
# [900]	eval-rmse:28.70231
# [999]	eval-rmse:28.53581
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 36.4685
# [0]	eval-rmse:50.35254
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# [100]	eval-rmse:37.19802
# [200]	eval-rmse:33.41152
# [300]	eval-rmse:31.85183
# [400]	eval-rmse:30.94965
# [500]	eval-rmse:30.39935
# [600]	eval-rmse:30.06157
# [700]	eval-rmse:29.81078
# [800]	eval-rmse:29.64834
# [900]	eval-rmse:29.47782
# [999]	eval-rmse:29.36151
# Training until validation scores don't improve for 50 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's rmse: 37.3362
# DRP  CV R² = 0.5851   RMSE = 32.84
#
# === Generating submission ===
# ✅ Saved → submission_deep_blend_fixed.csv
# Upload this file and check the leaderboard!
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# /Users/richard/.pyenv/versions/tf310/lib/python3.10/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
