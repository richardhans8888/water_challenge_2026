# %%
import warnings
warnings.filterwarnings("ignore")

# Data manipulation and analysis
import numpy as np
import pandas as pd

# Multi-dimensional arrays and datasets (e.g., NetCDF, Zarr)
import xarray as xr

from scipy.spatial import cKDTree

# Planetary Computer tools for STAC API access and authentication
import pystac_client
import planetary_computer as pc

from datetime import date
from tqdm import tqdm
import os

# %%
# The API-based method allows us to efficiently access TerraClimate data for specific regions and time periods

# Function to load TerraClimate data from the Planetary Computer
def load_terraclimate_dataset():
    catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )
    collection = catalog.get_collection("terraclimate")
    asset = collection.assets["zarr-abfs"]
    
    if "xarray:storage_options" in asset.extra_fields:
        ds = xr.open_zarr(
            asset.href,
            storage_options=asset.extra_fields["xarray:storage_options"],
            consolidated=True,
        )
    else:
        ds = xr.open_dataset(
            asset.href,
            **asset.extra_fields["xarray:open_kwargs"],
        )
    
    return ds

# %%
# Function to filter the data for the desired time range (2000-2021)
def filter_terraclimate_data(ds):
    # Filter by the time range 2000-2021
    ds_filtered = ds.sel(time=slice('2000-01-01', '2021-12-31'))
    
    return ds_filtered

# %%
# Function to assign the nearest TerraClimate grid point for latitude and longitude
def assign_nearest_climate(sa_df, climate_df, var_name):
    # Map nearest climate variable values to a new dataframe containing only the specified variable
    sa_coords = np.radians(sa_df[['Latitude', 'Longitude']].values)
    climate_coords = np.radians(climate_df[['Latitude', 'Longitude']].values)
    
    # Create a KD-tree for fast nearest neighbor search
    tree = cKDTree(climate_coords)
    dist, idx = tree.query(sa_coords, k=1)  # Find the nearest point
    
    # Extract the nearest climate data for the corresponding time
    nearest_climate = climate_df.iloc[idx].reset_index(drop=True)
    
    # Assign the nearest climate values to the dataframe
    sa_df['nearest_lat'] = nearest_climate['Latitude']
    sa_df['nearest_lon'] = nearest_climate['Longitude']
    sa_df['Sample Date'] = pd.to_datetime(sa_df['Sample Date'], errors='coerce')
    
    climate_values = climate_df.iloc[idx][var_name].values
    
    sa_df[var_name] = climate_values
    
    return sa_df

# %%
# Function to extract the TerraClimate features from the water quality training dataset
def extract_terra_features(water_quality_df, climate_df, tc_parameter):
    # Filter for the nearest parameter (e.g., PET)
    water_quality_df = assign_nearest_climate(water_quality_df, climate_df, tc_parameter)
    
    # Store the result
    return water_quality_df

# %%
# Load the water quality training dataset
water_quality_df = pd.read_csv("water_quality_training_dataset.csv")

# Check the first few rows of the dataset to confirm it was loaded correctly
water_quality_df.head()
# Out:
#     Latitude  Longitude Sample Date  Total Alkalinity  Electrical Conductance  \
# 0 -28.760833  17.730278  02-01-2011           128.912                   555.0
# 1 -26.861111  28.884722  03-01-2011            74.720                   162.9
# 2 -26.450000  28.085833  03-01-2011            89.254                   573.0
# 3 -27.671111  27.236944  03-01-2011            82.000                   203.6
# 4 -27.356667  27.286389  03-01-2011            56.100                   145.1
#
#    Dissolved Reactive Phosphorus
# 0                           10.0
# 1                          163.0
# 2                           80.0
# 3                          101.0
# 4                          151.0

# %%
# Function to load the TerraClimate dataset
def load_terraclimate_dataset():
    catalog = pystac_client.Client.open(
        "https://planetarycomputer.microsoft.com/api/stac/v1",
        modifier=pc.sign_inplace,
    )
    collection = catalog.get_collection("terraclimate")
    asset = collection.assets["zarr-abfs"]
    
    if "xarray:storage_options" in asset.extra_fields:
        ds = xr.open_zarr(
            asset.href,
            storage_options=asset.extra_fields["xarray:storage_options"],
            consolidated=True,
        )
    else:
        ds = xr.open_dataset(
            asset.href,
            **asset.extra_fields["xarray:open_kwargs"],
        )
    
    return ds

# Function to filter the TerraClimate dataset for the years 2000-2021
def filter_terraclimate_data(ds):
    # Filter by the time range 2000-2021
    ds_filtered = ds.sel(time=slice('2000-01-01', '2021-12-31'))
    
    return ds_filtered

# Load and filter TerraClimate dataset
ds_filtered = load_terraclimate_dataset()
climate_df = ds_filtered.to_dataframe().reset_index()

# Now climate_df contains the TerraClimate data, and we can proceed with the matching
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 33
#      31 # Load and filter TerraClimate dataset
#      32 ds_filtered = load_terraclimate_dataset()
# ---> 33 climate_df = ds_filtered.to_dataframe().reset_index()
#      35 # Now climate_df contains the TerraClimate data, and we can proceed with the matching
#
# File ~/.pyenv/versions/tf310/lib/python3.10/site-packages/xarray/core/dataset.py:7165, in Dataset.to_dataframe(self, dim_order)
#    7137 """Convert this dataset into a pandas.DataFrame.
#    7138
#    7139 Non-index variables in this dataset form the columns of the
#    (...)
#    7160
#    7161 """
#    7163 ordered_dims = self._normalize_dim_order(dim_order=dim_order)
# -> 7165 return self._to_dataframe(ordered_dims=ordered_dims)
#
# ...

# %%
# Example of usage:
tc_parameter = 'pet'  # Example: You can change this to the desired climate variable (e.g., 'pet', 'precipitation', etc.)
processed_water_quality_df = process_water_quality_data_in_batches(water_quality_df, climate_df, tc_parameter)

# Display the final processed data (with nearest latitude, longitude, and the climate variable)
processed_water_quality_df.head()
