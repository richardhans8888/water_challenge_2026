# %%
# Run in a separate cell / new notebook
import psutil
import time

while True:
    print(f"CPU: {psutil.cpu_percent():.1f}%   Memory: {psutil.virtual_memory().percent:.1f}%")
    time.sleep(10)
# Out:
# CPU: 12.2%   Memory: 57.3%
# CPU: 11.4%   Memory: 58.5%
# CPU: 10.5%   Memory: 57.1%
# CPU: 12.7%   Memory: 58.1%
# CPU: 10.9%   Memory: 57.9%
# CPU: 15.6%   Memory: 58.5%
# CPU: 14.0%   Memory: 57.4%
# CPU: 10.4%   Memory: 56.8%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 while True:
#       6     print(f"CPU: {psutil.cpu_percent():.1f}%   Memory: {psutil.virtual_memory().percent:.1f}%")
# ----> 7     time.sleep(10)
#
# KeyboardInterrupt:
